# %% [markdown]
# # Sales Data Analysis Mini Project

# %% [markdown]
# ### Name: Krunal Patil
# ### Branch: Computer A (TE)
# ### Email Id: krunalpatil_18273@aitpune.edu.in
# ### Contact No: 9527370923

# %% [markdown]
#  ###

# %% [markdown]
# ### Task 1: Identifying and importing essential libraries

# %%
#Import Numpy
import numpy as np
#Import pandas
import pandas as pd
#Import matplotlib library
import matplotlib.pyplot as plot

# %% [markdown]
# ### Task 2: Data loading and overview

# %% [markdown]
# ###### a. Load the dataset from a file

# %%
store_data = pd.read_excel('Superstore.xls', sheet_name='Orders')

# %% [markdown]
# ###### b. Look at the first 5 records of the data

# %%
store_data.head(5)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ###### c. Print the columns contained in the data

# %%
columns = store_data.columns
for column in columns: 
    print(column)
# Out:
# Row ID
# Order ID
# Order Date
# Ship Date
# Ship Mode
# Customer ID
# Customer Name
# Segment
# Country
# City
# State
# Postal Code
# Region
# Product ID
# Category
# Sub-Category
# Product Name
# Sales
# Quantity
# Discount
# Profit

# %% [markdown]
# ###### d. Print the attributes like count , mean , max , min, standard deviation etc

# %%
store_data.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %% [markdown]
# ###### e. Find out are there any missing or null values in the data for all columns

# %%
store_data.shape
# Out:
# (9994, 21)

# %%
store_data.count()
# Out:
# Row ID           9994
# Order ID         9994
# Order Date       9994
# Ship Date        9994
# Ship Mode        9994
# Customer ID      9994
# Customer Name    9994
# Segment          9994
# Country          9994
# City             9994
# State            9994
# Postal Code      9994
# Region           9994
# Product ID       9994
# Category         9994
# Sub-Category     9994
# Product Name     9994
# Sales            9994
# Quantity         9994
# Discount         9994
# Profit           9994
# dtype: int64

# %%
store_data.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### Task 3: Find out the per unit price from the data

# %% [markdown]
# ###### a. Convert date time field into pandas time object

# %%
store_data["Order Date"] = pd.to_datetime(store_data["Order Date"])
store_data["Ship Date"] = pd.to_datetime(store_data["Ship Date"])

store_data[['Order Date','Ship Date']].info()   # here the date is converted to datetime64 object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order Date  9994 non-null   datetime64[ns]
#  1   Ship Date   9994 non-null   datetime64[ns]
# dtypes: datetime64[ns](2)
# memory usage: 156.3 KB

# %% [markdown]
# ###### b. Find out the price per unit from the data and create a column for it in the same data

# %%
store_data["Price per unit"] = store_data["Sales"] / store_data["Quantity"]
store_data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ### Task 4: Find out the monthly revenue and analyze the findings

# %%
monthly_revenue = pd.DataFrame(store_data, columns = ['Ship Date'])
monthly_revenue.rename(columns={'Ship Date': 'Date'}, inplace=True)
monthly_revenue.sort_values(by = ['Date'], inplace=True)
monthly_revenue
# Out:
#            Date
# 7180 2014-01-07
# 7980 2014-01-07
# 5327 2014-01-08
# 739  2014-01-08
# 740  2014-01-08
# ...         ...
# 572  2018-01-04
# 571  2018-01-04
# 4239 2018-01-04
# 645  2018-01-05
# 5131 2018-01-05
#
# [9994 rows x 1 columns]

# %% [markdown]
# ###### a. Create a column with Year and month field only give a suitable name to it

# %%
monthly_revenue['Month'] = monthly_revenue['Date'].dt.strftime('%Y-%m')
monthly_revenue.drop(['Date'], axis=1, inplace=True)
monthly_revenue.drop_duplicates(inplace=True)
monthly_revenue
# Out:
#         Month
# 7180  2014-01
# 3796  2014-02
# 5511  2014-03
# 8463  2014-04
# 2891  2014-05
# 7858  2014-06
# 2276  2014-07
# 7341  2014-08
# 20    2014-09
# 1359  2014-10
# 7370  2014-11
# 5549  2014-12
# 8670  2015-01
# 8908  2015-02
# 5769  2015-03
# 2198  2015-04
# 7682  2015-05
# 1344  2015-06
# 4314  2015-07
# 6549  2015-08
# 9430  2015-09
# 2497  2015-10
# 1918  2015-11
# 4338  2015-12
# 4036  2016-01
# 7564  2016-02
# 4554  2016-03
# 1327  2016-04
# 610   2016-05
# 533   2016-06
# 8906  2016-07
# 7770  2016-08
# 742   2016-09
# 4518  2016-10
# 6240  2016-11
# 1503  2016-12
# 6803  2017-01
# 8589  2017-02
# 7534  2017-03
# 9787  2017-04
# 2961  2017-05
# 2433  2017-06
# 7453  2017-07
# 2220  2017-08
# 1942  2017-09
# 364   2017-10
# 3548  2017-11
# 4467  2017-12
# 953   2018-01

# %% [markdown]
# ###### b.Create a separate dataset from the data which will have two columns , one which is created in step a of this task and second the monthly sales / revenue

# %%
monthly_sales = monthly_revenue.groupby(monthly_revenue['Month'])['Sales'].sum()
monthly_sales = pd.DataFrame(monthly_sales)
monthly_sales
# Out:
#                Sales
# Month
# 2014-01   13275.1310
# 2014-02    5406.5280
# 2014-03   50708.3490
# 2014-04   30388.4650
# 2014-05   22478.8800
# 2014-06   35991.6556
# 2014-07   32990.5940
# 2014-08   30245.2420
# 2014-09   73126.6533
# 2014-10   35741.4770
# 2014-11   80182.1947
# 2014-12   59848.0235
# 2015-01   29594.7606
# 2015-02   12679.0770
# 2015-03   39269.6620
# 2015-04   25515.2535
# 2015-05   32587.9535
# 2015-06   29850.8300
# 2015-07   30400.2270
# 2015-08   28116.3142
# 2015-09   69615.8350
# 2015-10   32575.7155
# 2015-11   70634.8500
# 2015-12   78602.0237
# 2016-01   19130.0570
# 2016-02   26954.0850
# 2016-03   48795.9100
# 2016-04   41028.2980
# 2016-05   46520.1840
# 2016-06   48272.7220
# 2016-07   37595.9470
# 2016-08   32031.5793
# 2016-09   70460.8006
# 2016-10   60858.1993
# 2016-11   74664.1848
# 2016-12  105013.7860
# 2017-01   42297.0440
# 2017-02   23506.7824
# 2017-03   52891.3850
# 2017-04   40021.6803
# 2017-05   44774.9324
# 2017-06   47220.4981
# ...

# %% [markdown]
# ###### c. Plot this dataset

# %%
monthly_sales.plot(y='Sales', kind = 'line')
plot.show()

# %% [markdown]
# ### Task 5:  Find out the yearly revenue and analyze the findings

# %% [markdown]
# ###### a. Create a column with Year field only give a suitable name to it

# %%
yearly_revenue = pd.DataFrame(store_data, columns = ['Ship Date'])
yearly_revenue.rename(columns={'Ship Date': 'Date'}, inplace=True)
yearly_revenue.sort_values(by = ['Date'], inplace=True)

yearly_revenue['Year'] = yearly_revenue['Date'].dt.strftime('%Y')
yearly_revenue.drop(['Date'], axis=1, inplace=True)

yearly_revenue
# Out:
#       Year
# 7180  2014
# 7980  2014
# 5327  2014
# 739   2014
# 740   2014
# ...    ...
# 572   2018
# 571   2018
# 4239  2018
# 645   2018
# 5131  2018
#
# [9994 rows x 1 columns]

# %% [markdown]
# ###### b. Create a separate dataset from the data which will have two columns , one which is created in step a of this task and second the yearly sales / revenue

# %%
yearly_revenue['Sales'] = store_data['Sales'].astype(float)
yearly_sales = yearly_revenue.groupby(yearly_revenue['Year'])['Sales'].sum()
yearly_sales = pd.DataFrame(yearly_sales)
yearly_sales
# Out:
#             Sales
# Year
# 2014  470383.1931
# 2015  479442.5020
# 2016  611325.7530
# 2017  730889.7154
# 2018    5159.6968

# %% [markdown]
# ###### c. Plot this dataset

# %%
yearly_sales.plot(y='Sales', kind = 'bar')
plot.show()

# %% [markdown]
# ### Task 6: Finding out the monthly growth rate and analyse the findings

# %% [markdown]
# ###### a. Create a column in the monthly revenue dataset for monthly growth rate

# %%
monthly_sales['Growth'] = monthly_sales['Sales'].pct_change()
monthly_sales
# Out:
#                Sales    Growth
# Month
# 2014-01   13275.1310       NaN
# 2014-02    5406.5280 -0.592733
# 2014-03   50708.3490  8.379097
# 2014-04   30388.4650 -0.400721
# 2014-05   22478.8800 -0.260282
# 2014-06   35991.6556  0.601132
# 2014-07   32990.5940 -0.083382
# 2014-08   30245.2420 -0.083216
# 2014-09   73126.6533  1.417790
# 2014-10   35741.4770 -0.511239
# 2014-11   80182.1947  1.243393
# 2014-12   59848.0235 -0.253600
# 2015-01   29594.7606 -0.505501
# 2015-02   12679.0770 -0.571577
# 2015-03   39269.6620  2.097202
# 2015-04   25515.2535 -0.350255
# 2015-05   32587.9535  0.277195
# 2015-06   29850.8300 -0.083992
# 2015-07   30400.2270  0.018405
# 2015-08   28116.3142 -0.075128
# 2015-09   69615.8350  1.475994
# 2015-10   32575.7155 -0.532065
# 2015-11   70634.8500  1.168328
# 2015-12   78602.0237  0.112794
# 2016-01   19130.0570 -0.756621
# 2016-02   26954.0850  0.408991
# 2016-03   48795.9100  0.810335
# 2016-04   41028.2980 -0.159186
# 2016-05   46520.1840  0.133856
# ...

# %% [markdown]
# ###### b. Find out the maximum monthly growth rate

# %%
monthly_sales.sort_values('Growth', ascending=False).head(1)
# Out:
#              Sales    Growth
# Month
# 2014-03  50708.349  8.379097

# %% [markdown]
# ###### c. Plot this dataset

# %%
monthly_sales.plot(y='Growth', title="Growth rate", kind = 'bar');
plot.show();

# %% [markdown]
# ### Task 7: Finding out the most and least sold product id

# %% [markdown]
# ###### a. Create a new dataset including the product ids and total quantities sold for that id

# %%
product = pd.DataFrame(store_data, columns = ['Row ID', 'Product ID'])
product['Quantities sold'] = product.groupby(['Product ID']).transform('count')
product.drop(['Row ID'], axis=1, inplace=True)
product.drop_duplicates(inplace=True)
product = product.reset_index(drop=True)
product
# Out:
#            Product ID  Quantities sold
# 0     FUR-BO-10001798                4
# 1     FUR-CH-10000454               12
# 2     OFF-LA-10000240                7
# 3     FUR-TA-10000577                8
# 4     OFF-ST-10000760                5
# ...               ...              ...
# 1857  TEC-PH-10002817                1
# 1858  TEC-MA-10003589                1
# 1859  OFF-AP-10003099                1
# 1860  TEC-PH-10002645                1
# 1861  OFF-ST-10001627                1
#
# [1862 rows x 2 columns]

# %% [markdown]
# ###### b. Find out the most sold product from the created dataset

# %%
store_data.loc[ store_data[ 'Product ID'] == product.max()['Product ID'] ]['Product Name'].unique()[0]
# Out:
# 'GE 30524EE4'

# %% [markdown]
# ###### c. Find out the least sold product from the created dataset

# %%
store_data.loc[ store_data[ 'Product ID'] == product.min()['Product ID'] ]['Product Name'].unique()[0]
# Out:
# 'Bush Birmingham Collection Bookcase, Dark Cherry'

# %% [markdown]
# ### Task 8 Finding out the customer who bought most and least from us in terms of quantity

# %%
quantity = pd.DataFrame(store_data)
quantity = quantity.groupby(['Customer ID', 'Customer Name'])['Quantity'].sum()
quantity = pd.DataFrame(quantity)
quantity.drop_duplicates(inplace=True)
quantity.reset_index(inplace=True)
quantity
# Out:
#     Customer ID   Customer Name  Quantity
# 0      AA-10315      Alex Avila        30
# 1      AA-10375    Allen Armold        41
# 2      AA-10480    Andrew Allen        36
# 3      AA-10645   Anna Andreadi        64
# 4      AB-10015   Aaron Bergman        13
# ..          ...             ...       ...
# 112    SJ-20125   Sanjit Jacobs       104
# 113    SM-20950  Suzanne McNair        94
# 114    SV-20365     Seth Vernon       109
# 115    WB-21850   William Brown       146
# 116    XP-21865    Xylona Preis       100
#
# [117 rows x 3 columns]

# %% [markdown]
# ###### b. Find out the customer name and quantity, who bought maximum in quantity

# %%
quantity.loc[ quantity['Quantity'] == quantity.max()['Quantity']]
# Out:
#    Customer ID     Customer Name  Quantity
# 92    JD-15895  Jonathan Doherty       150

# %% [markdown]
# ###### c. Find out the customer name and quantity, who bought minimum in quantity

# %%
quantity.loc[ quantity['Quantity'] == quantity.min()['Quantity']]
# Out:
#    Customer ID      Customer Name  Quantity
# 35    AO-10810  Anthony O'Donnell         2

# %% [markdown]
# ### Task 9: Finding out the customer who bought most and least from us in terms of value

# %%
sales_df = pd.DataFrame(store_data)
sales_df = sales_df.groupby(['Customer ID', 'Customer Name'])['Sales'].sum()
sales_df = pd.DataFrame(sales_df)
sales_df.drop_duplicates(inplace=True)
sales_df.reset_index(inplace=True)
sales_df
# Out:
#     Customer ID       Customer Name     Sales
# 0      AA-10315          Alex Avila  5563.560
# 1      AA-10375        Allen Armold  1056.390
# 2      AA-10480        Andrew Allen  1790.512
# 3      AA-10645       Anna Andreadi  5086.935
# 4      AB-10015       Aaron Bergman   886.156
# ..          ...                 ...       ...
# 788    XP-21865        Xylona Preis  2374.658
# 789    YC-21895      Yoseph Carroll  5454.350
# 790    YS-21880       Yana Sorensen  6720.444
# 791    ZC-21910    Zuschuss Carroll  8025.707
# 792    ZD-21925  Zuschuss Donatelli  1493.944
#
# [793 rows x 3 columns]

# %%
sales_df.loc[ sales_df['Sales'] == sales_df.max()['Sales']]
# Out:
#     Customer ID Customer Name     Sales
# 700    SM-20320   Sean Miller  25043.05

# %%
sales_df.loc[ sales_df['Sales'] == sales_df.min()['Sales']]
# Out:
#     Customer ID  Customer Name  Sales
# 760    TS-21085  Thais Sissman  4.833

# %% [markdown]
# ### Task 10: Finding out the majority and minority customer cities on basis of

# %%
city_df = pd.DataFrame(store_data, columns = ['Customer ID', 'Customer Name', 'City', 'Sales', 'Quantity'])
city_df = city_df.set_index('City')
city_df
# Out:
#                 Customer ID     Customer Name     Sales  Quantity
# City
# Henderson          CG-12520       Claire Gute  261.9600         2
# Henderson          CG-12520       Claire Gute  731.9400         3
# Los Angeles        DV-13045   Darrin Van Huff   14.6200         2
# Fort Lauderdale    SO-20335    Sean O'Donnell  957.5775         5
# Fort Lauderdale    SO-20335    Sean O'Donnell   22.3680         2
# ...                     ...               ...       ...       ...
# Miami              TB-21400  Tom Boeckenhauer   25.2480         3
# Costa Mesa         DB-13060       Dave Brooks   91.9600         2
# Costa Mesa         DB-13060       Dave Brooks  258.5760         2
# Costa Mesa         DB-13060       Dave Brooks   29.6000         4
# Westminster        CC-12220      Chris Cortes  243.1600         2
#
# [9994 rows x 4 columns]

# %% [markdown]
# ###### a. Number of customers

# %%
city_customers = city_df.groupby(['City']).transform('count')
city_customers.drop(['Customer ID', 'Sales', 'Quantity'], axis=1, inplace=True)
city_customers.rename(columns={'Customer Name': 'CustomerCount'}, inplace=True)
city_customers.drop_duplicates(inplace=True)
city_customers
# Out:
#                  CustomerCount
# City
# Henderson                   51
# Los Angeles                747
# Fort Lauderdale             15
# Concord                     31
# Seattle                    428
# ...                        ...
# Mesa                        28
# Salem                       40
# Hialeah                     18
# Lancaster                   46
# Baltimore                   43
#
# [70 rows x 1 columns]

# %% [markdown]
# ###### 1. Majority customer cities on the basis of customers

# %%
city_customers.sort_values('CustomerCount', ascending=False).head(1)
# Out:
#                CustomerCount
# City
# New York City            915

# %% [markdown]
# ###### 2. Minority customer cities on the basis of customers

# %%
city_customers.sort_values('CustomerCount', ascending=False).tail(1)
# Out:
#            CustomerCount
# City
# Melbourne              1

# %% [markdown]
# ###### b. Sales value

# %%
city_sales = city_df.groupby(['City'])['Sales'].sum()
city_sales = pd.DataFrame(city_sales)
city_sales.drop_duplicates(inplace=True)
city_sales
# Out:
#                 Sales
# City
# Aberdeen       25.500
# Abilene         1.392
# Akron        2729.986
# Albuquerque  2220.160
# Alexandria   5519.570
# ...               ...
# Woonsocket    195.550
# Yonkers      7657.666
# York          817.978
# Yucaipa        50.800
# Yuma          840.865
#
# [529 rows x 1 columns]

# %% [markdown]
# ###### 1. Majority customer cities on the basis of sales

# %%
city_sales.sort_values('Sales', ascending=False).head(1)
# Out:
#                     Sales
# City
# New York City  256368.161

# %% [markdown]
# ###### 2. Minority customer cities on the basis of sales

# %%
city_sales.sort_values('Sales', ascending=False).tail(1)
# Out:
#          Sales
# City
# Abilene  1.392

# %% [markdown]
# ###### c. Number of quantity sold

# %%
city_quantity = city_df.groupby(['City'])['Quantity'].sum()
city_quantity = pd.DataFrame(city_quantity)
city_quantity.drop_duplicates(inplace=True)
city_quantity
# Out:
#              Quantity
# City
# Aberdeen            3
# Abilene             2
# Akron              65
# Alexandria         84
# Allen              13
# ...               ...
# Tallahassee        89
# Toledo            122
# Tucson            145
# Wilmington        157
# Yonkers            57
#
# [143 rows x 1 columns]

# %% [markdown]
# ###### 1. Majority customer cities on the basis of quantity sold

# %%
city_quantity.sort_values('Quantity', ascending=False).head(1)
# Out:
#                Quantity
# City
# New York City      3417

# %% [markdown]
# ###### 2. Minority customer cities on the basis of quantity sold

# %%
city_quantity.sort_values('Quantity', ascending=False).tail(1)
# Out:
#         Quantity
# City
# Elyria         1

# %% [markdown]
# ### Task 11: Find out the most and least sold product category from the store

# %%
sold_product = pd.DataFrame(store_data, columns = ['Category', 'Sub-Category', 'Sales', 'Quantity'])
sold_product
# Out:
#              Category Sub-Category     Sales  Quantity
# 0           Furniture    Bookcases  261.9600         2
# 1           Furniture       Chairs  731.9400         3
# 2     Office Supplies       Labels   14.6200         2
# 3           Furniture       Tables  957.5775         5
# 4     Office Supplies      Storage   22.3680         2
# ...               ...          ...       ...       ...
# 9989        Furniture  Furnishings   25.2480         3
# 9990        Furniture  Furnishings   91.9600         2
# 9991       Technology       Phones  258.5760         2
# 9992  Office Supplies        Paper   29.6000         4
# 9993  Office Supplies   Appliances  243.1600         2
#
# [9994 rows x 4 columns]

# %% [markdown]
# ###### a.Value based

# %%
sold_product_sales = pd.DataFrame(sold_product)
sold_product_sales = sold_product_sales.groupby(sold_product_sales['Category'])['Sales'].sum()
sold_product_sales = pd.DataFrame(sold_product_sales)
sold_product_sales.drop_duplicates(inplace=True)
sold_product_sales
# Out:
#                        Sales
# Category
# Furniture        741999.7953
# Office Supplies  719047.0320
# Technology       836154.0330

# %% [markdown]
# ###### 1. Most sold product category

# %%
sold_product_sales.sort_values('Sales', ascending=False).head(1)
# Out:
#                  Sales
# Category
# Technology  836154.033

# %% [markdown]
# ###### 2. Least sold product category

# %%
sold_product_sales.sort_values('Sales', ascending=False).tail(1)
# Out:
#                       Sales
# Category
# Office Supplies  719047.032

# %% [markdown]
# ###### b. Quantity based

# %%
sold_product_quantity = pd.DataFrame(sold_product)
sold_product_quantity = sold_product_quantity.groupby(['Category'])['Quantity'].sum()
sold_product_quantity = pd.DataFrame(sold_product_quantity)
sold_product_quantity.drop_duplicates(inplace=True)
sold_product_quantity
# Out:
#                  Quantity
# Category
# Furniture            8028
# Office Supplies     22906
# Technology           6939

# %% [markdown]
# ###### 1. Most sold product category

# %%
sold_product_quantity.sort_values('Quantity', ascending=False).head(1)
# Out:
#                  Quantity
# Category
# Office Supplies     22906

# %% [markdown]
# ###### 2. Least sold product category

# %%
sold_product_quantity.sort_values('Quantity', ascending=False).tail(1)
# Out:
#             Quantity
# Category
# Technology      6939

# %% [markdown]
# ### Task 12: Find out the most and least sold product sub category from the store

# %% [markdown]
# ###### a.Value based

# %%
sold_subproduct_sales = sold_product.groupby(sold_product['Sub-Category'])['Sales'].sum()
sold_subproduct_sales = pd.DataFrame(sold_subproduct_sales)
sold_subproduct_sales.drop_duplicates(inplace=True)
sold_subproduct_sales
# Out:
#                     Sales
# Sub-Category
# Accessories   167380.3180
# Appliances    107532.1610
# Art            27118.7920
# Binders       203412.7330
# Bookcases     114879.9963
# Chairs        328449.1030
# Copiers       149528.0300
# Envelopes      16476.4020
# Fasteners       3024.2800
# Furnishings    91705.1640
# Labels         12486.3120
# Machines      189238.6310
# Paper          78479.2060
# Phones        330007.0540
# Storage       223843.6080
# Supplies       46673.5380
# Tables        206965.5320

# %% [markdown]
# ###### 1. Most sold product sub-category

# %%
sold_subproduct_sales.sort_values('Sales', ascending=False).head(1)
# Out:
#                    Sales
# Sub-Category
# Phones        330007.054

# %% [markdown]
# ###### 2. Least sold product sub-category

# %%
sold_subproduct_sales.sort_values('Sales', ascending=False).tail(1)
# Out:
#                 Sales
# Sub-Category
# Fasteners     3024.28

# %% [markdown]
# ###### b. Quantity based

# %%
sold_subproduct_quantity = sold_product.groupby(sold_product['Sub-Category'])['Quantity'].sum()
sold_subproduct_quantity = pd.DataFrame(sold_subproduct_quantity)
sold_subproduct_quantity.drop_duplicates(inplace=True)
sold_subproduct_quantity
# Out:
#               Quantity
# Sub-Category
# Accessories       2976
# Appliances        1729
# Art               3000
# Binders           5974
# Bookcases          868
# Chairs            2356
# Copiers            234
# Envelopes          906
# Fasteners          914
# Furnishings       3563
# Labels            1400
# Machines           440
# Paper             5178
# Phones            3289
# Storage           3158
# Supplies           647
# Tables            1241

# %% [markdown]
# ###### 1. Most sold product sub-category

# %%
sold_subproduct_quantity.sort_values('Quantity', ascending=False).head(1)
# Out:
#               Quantity
# Sub-Category
# Binders           5974

# %% [markdown]
# ###### 2. Least sold product sub-category

# %%
sold_subproduct_quantity.sort_values('Quantity', ascending=False).tail(1)
# Out:
#               Quantity
# Sub-Category
# Copiers            234
